# %%
#Import dependencies
import pandas as pd

# %%
#Read csv
gdp_df = pd.read_csv('World_Bank_Files/Resources/etl_project_gdp.csv')

#grab the 4th row and set it to be the header
new_header = gdp_df.iloc[3]
gdp_df.columns = new_header

#remove first 4 rows from df
gdp_df = gdp_df.iloc[4:]

# %%
#drop extra columns
gdp_df = gdp_df.drop(columns=['Indicator Name', 'Indicator Code',1960.0,2020.0])
gdp_df = gdp_df.reset_index(drop = True)
gdp_df
# Out:
# 3    Country Name Country Code    1961.0    1962.0    1963.0     1964.0  \
# 0           Aruba          ABW       NaN       NaN       NaN        NaN
# 1     Afghanistan          AFG       NaN       NaN       NaN        NaN
# 2          Angola          AGO       NaN       NaN       NaN        NaN
# 3         Albania          ALB       NaN       NaN       NaN        NaN
# 4         Andorra          AND       NaN       NaN       NaN        NaN
# ..            ...          ...       ...       ...       ...        ...
# 259        Kosovo          XKX       NaN       NaN       NaN        NaN
# 260   Yemen, Rep.          YEM       NaN       NaN       NaN        NaN
# 261  South Africa          ZAF  3.844751  6.177883  7.373613   7.939782
# 262        Zambia          ZMB  1.361382 -2.490839  3.272393  12.214048
# 263      Zimbabwe          ZWE  6.316157  1.434471  6.244345  -1.106172
#
# 3       1965.0    1966.0    1967.0    1968.0  ...     2010.0     2011.0  \
# ...

# %%
gdp_df = gdp_df.rename(columns= {'Country Name':'country_name',
 'Country Code':'country_code',1961.0:'year_1961',1962.0:'year_1962', 1963.0:'year_1963', 1964.0:'year_1964', 
                                 1965.0:'year_1965',1966.0:'year_1966', 1967.0:'year_1967', 1968.0:'year_1968', 
                                 1969.0:'year_1969', 1970.0:'year_1970', 1971.0:'year_1971', 1972.0:'year_1972',
                                 1973.0:'year_1973', 1974.0:'year_1974', 1975.0:'year_1975', 1976.0:'year_1976', 
                                 1977.0:'year_1977', 1978.0:'year_1978', 1979.0:'year_1979',1980.0:'year_1980', 
                                 1981.0:'year_1981', 1982.0:'year_1982', 1983.0:'year_1983', 1984.0:'year_1984', 
                                 1985.0:'year_1985', 1986.0:'year_1986',1987.0:'year_1987', 1988.0:'year_1988', 
                                 1989.0:'year_1989', 1990.0:'year_1990', 1991.0:'year_1991', 1992.0:'year_1992', 
                                 1993.0:'year_1993',1994.0:'year_1994', 1995.0:'year_1995', 1996.0:'year_1996', 
                                 1997.0:'year_1997', 1998.0:'year_1998', 1999.0:'year_1999', 2000.0:'year_2000',
                                 2001.0:'year_2001', 2002.0:'year_2002', 2003.0:'year_2003', 2004.0:'year_2004', 
                                 2005.0:'year_2005', 2006.0:'year_2006', 2007.0:'year_2007', 2008.0:'year_2008', 
                                 2009.0:'year_2009', 2010.0:'year_2010', 2011.0:'year_2011', 2012.0:'year_2012', 
                                 2013.0:'year_2013', 2014.0:'year_2014',2015.0:'year_2015', 2016.0:'year_2016', 
                                 2017.0:'year_2017', 2018.0:'year_2018', 2019.0:'year_2019'})

# %%
list(gdp_df.columns)
# Out:
# ['country_name',
#  'country_code',
#  'year_1961',
#  'year_1962',
#  'year_1963',
#  'year_1964',
#  'year_1965',
#  'year_1966',
#  'year_1967',
#  'year_1968',
#  'year_1969',
#  'year_1970',
#  'year_1971',
#  'year_1972',
#  'year_1973',
#  'year_1974',
#  'year_1975',
#  'year_1976',
#  'year_1977',
#  'year_1978',
#  'year_1979',
#  'year_1980',
#  'year_1981',
#  'year_1982',
#  'year_1983',
#  'year_1984',
#  'year_1985',
#  'year_1986',
#  'year_1987',
#  'year_1988',
#  'year_1989',
#  'year_1990',
#  'year_1991',
#  'year_1992',
#  'year_1993',
#  'year_1994',
#  'year_1995',
#  'year_1996',
#  'year_1997',
#  'year_1998',
#  'year_1999',
#  'year_2000',
#  'year_2001',
#  'year_2002',
#  'year_2003',
#  'year_2004',
#  'year_2005',
#  'year_2006',
#  'year_2007',
#  'year_2008',
#  'year_2009',
#  'year_2010',
#  'year_2011',
#  'year_2012',
#  'year_2013',
#  'year_2014',
#  'year_2015',
#  'year_2016',
#  'year_2017',
#  'year_2018',
#  'year_2019']

# %%
gdp_df.dtypes
# Out:
# 3
# country_name     object
# country_code     object
# year_1961       float64
# year_1962       float64
# year_1963       float64
#                  ...
# year_2015       float64
# year_2016       float64
# year_2017       float64
# year_2018       float64
# year_2019       float64
# Length: 61, dtype: object

# %%
gdp_df.head()
# Out:
# 3 country_name country_code  year_1961  year_1962  year_1963  year_1964  \
# 0        Aruba          ABW        NaN        NaN        NaN        NaN
# 1  Afghanistan          AFG        NaN        NaN        NaN        NaN
# 2       Angola          AGO        NaN        NaN        NaN        NaN
# 3      Albania          ALB        NaN        NaN        NaN        NaN
# 4      Andorra          AND        NaN        NaN        NaN        NaN
#
# 3  year_1965  year_1966  year_1967  year_1968  ...  year_2010  year_2011  \
# 0        NaN        NaN        NaN        NaN  ...  -3.685029   3.446055
# 1        NaN        NaN        NaN        NaN  ...  14.362441   0.426355
# 2        NaN        NaN        NaN        NaN  ...   4.403933   3.471976
# 3        NaN        NaN        NaN        NaN  ...   3.706892   2.545322
# 4        NaN        NaN        NaN        NaN  ...  -1.974958  -0.008070
#
# 3  year_2012  year_2013  year_2014  year_2015  year_2016  year_2017  \
# ...

# %%
gdp_df = gdp_df.round(decimals=5)
gdp_df
# Out:
# 3    country_name country_code  year_1961  year_1962  year_1963  year_1964  \
# 0           Aruba          ABW        NaN        NaN        NaN        NaN
# 1     Afghanistan          AFG        NaN        NaN        NaN        NaN
# 2          Angola          AGO        NaN        NaN        NaN        NaN
# 3         Albania          ALB        NaN        NaN        NaN        NaN
# 4         Andorra          AND        NaN        NaN        NaN        NaN
# ..            ...          ...        ...        ...        ...        ...
# 259        Kosovo          XKX        NaN        NaN        NaN        NaN
# 260   Yemen, Rep.          YEM        NaN        NaN        NaN        NaN
# 261  South Africa          ZAF    3.84475    6.17788    7.37361    7.93978
# 262        Zambia          ZMB    1.36138   -2.49084    3.27239   12.21405
# 263      Zimbabwe          ZWE    6.31616    1.43447    6.24434   -1.10617
#
# ...

# %%
#export gdp data into a .csv
gdp_df.to_csv('World_Bank_Files/Resources/clean_gdp_data.csv', index = False, header=True)

# %%
#read in regional metadata
regional_df = pd.read_csv('World_Bank_Files/Resources/etl_regional_metadata.csv')

# %%
#double check that the data types are the same for joining
regional_df.dtypes
# Out:
# Country Code    object
# Region          object
# IncomeGroup     object
# SpecialNotes    object
# TableName       object
# dtype: object

# %%
regional_df = regional_df.rename(columns= {'Country Code':'country_code',
                                           'Region':'region', 'IncomeGroup':'income_group',
                                           'SpecialNotes':'special_notes',
                                          'TableName':'country_name'})

# %%
list(regional_df.columns)
# Out:
# ['country_code', 'region', 'income_group', 'special_notes', 'country_name']

# %%
regional_df.head()
# Out:
#   country_code                     region         income_group special_notes  \
# 0          ABW  Latin America & Caribbean          High income           NaN
# 1          AFG                 South Asia           Low income           NaN
# 2          AGO         Sub-Saharan Africa  Lower middle income           NaN
# 3          ALB      Europe & Central Asia  Upper middle income           NaN
# 4          AND      Europe & Central Asia          High income           NaN
#
#   country_name
# 0        Aruba
# 1  Afghanistan
# 2       Angola
# 3      Albania
# 4      Andorra

# %%
#export regional data into a .csv
regional_df.to_csv('World_Bank_Files/Resources/clean_regional_data.csv', index = False, header=True)
