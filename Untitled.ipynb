# %%
import pandas as pd

# %%
gdp_df = pd.read_csv('World_Bank_files/etl_project_gdp.csv')
gdp_df.head()
# Out:
#          Data Source World Development Indicators             Unnamed: 2  \
# 0                NaN                          NaN                    NaN
# 1  Last Updated Date                    3/19/2021                    NaN
# 2                NaN                          NaN                    NaN
# 3       Country Name                 Country Code         Indicator Name
# 4              Aruba                          ABW  GDP growth (annual %)
#
#           Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0                NaN         NaN         NaN         NaN         NaN
# 1                NaN         NaN         NaN         NaN         NaN
# 2                NaN         NaN         NaN         NaN         NaN
# 3     Indicator Code      1960.0      1961.0      1962.0      1963.0
# 4  NY.GDP.MKTP.KD.ZG         NaN         NaN         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  ...  Unnamed: 55  Unnamed: 56  Unnamed: 57  \
# 0         NaN         NaN  ...          NaN          NaN          NaN
# 1         NaN         NaN  ...          NaN          NaN          NaN
# 2         NaN         NaN  ...          NaN          NaN          NaN
# 3      1964.0      1965.0  ...  2011.000000  2012.000000  2013.000000
# 4         NaN         NaN  ...     3.446055    -1.369863     4.198232
#
#    Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3       2014.0  2015.000000       2016.0  2017.000000       2018.0
# 4          0.3     5.700001          2.1     1.999999          NaN
#
#    Unnamed: 63  Unnamed: 64
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3       2019.0       2020.0
# 4          NaN          NaN
#
# [5 rows x 65 columns]

# %%
## grab the 4th row and set it to be the header
new_header = gdp_df.iloc[3]
gdp_df.columns = new_header

## remove first 4 rows from df
gdp_df = gdp_df.iloc[4:]
gdp_df.head()
# Out:
# 3 Country Name Country Code         Indicator Name     Indicator Code  1960.0  \
# 4        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG     NaN
# 5  Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG     NaN
# 6       Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG     NaN
# 7      Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG     NaN
# 8      Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG     NaN
#
# 3  1961.0  1962.0  1963.0  1964.0  1965.0  ...    2011.0     2012.0    2013.0  \
# 4     NaN     NaN     NaN     NaN     NaN  ...  3.446055  -1.369863  4.198232
# 5     NaN     NaN     NaN     NaN     NaN  ...  0.426355  12.752287  5.600745
# 6     NaN     NaN     NaN     NaN     NaN  ...  3.471976   8.542188  4.954545
# 7     NaN     NaN     NaN     NaN     NaN  ...  2.545322   1.417526  1.001987
# 8     NaN     NaN     NaN     NaN     NaN  ... -0.008070  -4.974444 -3.547597
#
# 3    2014.0    2015.0    2016.0    2017.0    2018.0    2019.0  2020.0
# 4  0.300000  5.700001  2.100000  1.999999       NaN       NaN     NaN
# 5  2.724543  1.451315  2.260314  2.647003  1.189228  3.911603     NaN
# 6  4.822628  0.943572 -2.580050 -0.147213 -2.003630 -0.624644     NaN
# 7  1.774487  2.218752  3.314805  3.802197  4.071301  2.240070     NaN
# 8  2.504466  1.434140  3.709678  0.346072  1.588765  1.849238     NaN
#
# [5 rows x 65 columns]
